# %% [markdown]
# <a href="https://colab.research.google.com/github/40love/licenta2019/blob/master/Colab_WorkingVersion2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Fisier Antrenament

# %%
#run once to import to files your google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
'''MAININPUT
Created on Apr 24, 2019

@author: PITA
'''
#from Package import GetInput, Retea 
import numpy
limita = 0.5
def tipareste(x):
    lst=[]
    for it in range(len(x)):
        for jt in range(len(x[it])):
          if x[it][jt] not in lst:
              lst.append(x[it][jt])
    lst.sort(reverse=True)
    print(lst)  
    return lst
def analizeazaPoza(poza):
    import cv2
    pixeli = GetInput.prelucreazaImagineInputAux(poza)
    image = cv2.imread(poza)
    model = Retea.getModel()
    pred = model.predict(numpy.array([pixeli]))
    suma = 0
    cnt = 0
    for it in range(len(pred[0])):
        
        for jt in range(len(pred[0][it])):
            
            if pred[0][it][jt]>limita:
                suma +=pred[0][it][jt]
                cnt +=1
    medie = (float(suma)/float(cnt))
    for it in range(len(pred[0])):
        for jt in range(len(pred[0][it])):
            if pred[0][it][jt]>medie:    
                cv2.circle(image,(it,jt), 3, (0,0,255), -1)
    #tipareste(pred)
    cv2.imshow("IataCarii", image)
    cv2.waitKey(0)
    print(medie)
    print(pred.shape)
    print(pred)
    
    
def analizeazaPozaDebug(poza):
    import cv2
    from keras.models import model_from_json
    #model = Antrenament.incarcaModel()
    json_file = open('model.json', 'r')
    loaded_model_json = json_file.read()
    json_file.close()
    loaded_model = model_from_json(loaded_model_json)
    # load weights into new model
    loaded_model.load_weights("model.h5")
    print("Loaded model from disk")
    model = loaded_model
    pixeli = GetInput.prelucreazaImagineInputAux(poza)
    image = cv2.imread(poza)
    
    pred = model.predict(numpy.array([pixeli]))
    suma = 0
    cnt = 0
    for it in range(len(pred[0])):
        
        for jt in range(len(pred[0][it])):
            
            if pred[0][it][jt]>limita:
                suma +=pred[0][it][jt]
                cnt +=1
    medie = (float(suma)/float(cnt))
    #medie = 5000000
    for it in range(len(pred[0])):
        for jt in range(len(pred[0][it])):
            if pred[0][it][jt]>medie:    
                #cv2.circle(image,(it*4,jt*4), 3, (0,0,255), -1)
                pass
    lst = tipareste(pred[0])
    for kt in lst :
        for it in range(len(pred[0])):
            for jt in range(len(pred[0][it])):
                if pred[0][it][jt]==kt:    
                    cv2.circle(image,(it,jt), 3, (0,0,255), -1)
                    cv2.imshow("IataCarii", image)
                    cv2.waitKey(0)
                    
    #cv2.imshow("IataCarii", image)
    cv2.waitKey(0)
    print(medie)
    print(pred.shape)
    print(pred)
    
'''GetInput
Created on Apr 24, 2019
@author: PITA
'''
from PIL import Image
import numpy
import os
from builtins import isinstance

directorImaginiInput="/content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB"
directorImaginiOutput="/content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output"
dimensiune = (256,256)
dimensiuneOut = (64,64)
factorZoom = dimensiune[0]/dimensiuneOut[0]
def tranformaImagine(imagine):
    imagine=Image.open(imagine).convert('L')
    #image = color.rgb2gray(imagine)
    image_resized = imagine.resize(dimensiune,Image.ANTIALIAS)
    pixels = list(image_resized.getdata())
    width, height = image_resized.size
    pixels = [pixels[i * width:(i + 1) * width] for i in range(height)]
    return pixels

def getPixeliOutput(fisier):
    output = []
    # import the necessary packages
    import imutils
    import cv2
    

    # load the image, convert it to grayscale, blur it slightly,
    # and threshold it
    image = cv2.imread(fisier)
    hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
    lower_red = numpy.array([0,100,100])
    upper_red = numpy.array([179, 255, 255])
    mask = cv2.inRange(hsv, lower_red, upper_red)
    #cv2.imshow("HSV", hsv)
   # cv2.waitKey(0)
   # cv2.imshow("Mask", mask)
   # cv2.waitKey(0)
    
    blurred = cv2.GaussianBlur(mask, (5, 5), 0)
    thresh = cv2.threshold(blurred, 60, 255, cv2.THRESH_BINARY)[1]
    # find contours in the thresholded image
    cnts = cv2.findContours(thresh.copy(), cv2.RETR_EXTERNAL,cv2.CHAIN_APPROX_SIMPLE)
    cnts = imutils.grab_contours(cnts)
    # Create a black image
    img = numpy.zeros((600,600,3), numpy.uint8)
    for c in cnts:
        # compute the center of the contour
        M = cv2.moments(c)
        print(M["m10"])
        print(M["m00"])
        print(M["m01"])
        if M["m00"] != 0.0 :
            cX = int(M["m10"] / M["m00"])
            cY = int(M["m01"] / M["m00"])   
            output.append([cX,cY])
            cv2.circle(img,(cX,cY), 3, (0,0,255), -1)
    
    print(fisier)  
    print(output)
    #cv2.imshow("Mask", img)
    #cv2.waitKey(0)
    return output

def prelucreazaImagineOutputAux(fisier):
    numeComplet = os.path.join(directorImaginiOutput,fisier)
    pixeliOutput = getPixeliOutput(numeComplet)
    cheieDictionar = fisier.split(".")[0]
    if cheieDictionar not in dictionarImagini:
        dictionarImagini[cheieDictionar]=[0,0]
    y_t = []
    y = [-1]*dimensiuneOut[0]
    for _ in range(dimensiuneOut[1]):
        y_t.append(y)
    for pixel in pixeliOutput:
        for kt in range(int(pixel[0]/factorZoom)-1,int(pixel[0]/factorZoom)+2):
            for lt in range(int(pixel[1]/factorZoom)-1,int(pixel[1]/factorZoom)+2):
                y_t[kt][lt] = 1
        #y_t[int(pixel[0]/factorZoom)][int(pixel[1]/factorZoom)] = 1
    #y_t = numpy.reshape(y_t,(dimensiune[0],dimensiune[1],1))
    dictionarImagini[cheieDictionar][1]=y_t
    return y_t

def prelucreazaImagineOutput(fisier):
    fisierMirror = mirrorImage(fisier,directorImaginiOutput)
    
    prelucreazaImagineOutputAux(fisier)
    prelucreazaImagineOutputAux(fisierMirror)
    
def prelucreazaImagineInputAux(fisier):
    numeComplet = os.path.join(directorImaginiInput,fisier)
    img = tranformaImagine(numeComplet)
    img=numpy.reshape(img,(dimensiune[0],dimensiune[1],1))
    if fisier.split(".")[0] not in dictionarImagini:
        dictionarImagini[fisier.split(".")[0]] = [0,0]
    
    dictionarImagini[fisier.split(".")[0]][0]=img
    return img
    
    
def mirrorImage(fisier,director):
    numeComplet = os.path.join(director,fisier)
    image_obj = Image.open(numeComplet)
    rotated_image = image_obj.transpose(Image.FLIP_LEFT_RIGHT)
    fisierMirror = fisier.split(".")[0]+"mirror."+fisier.split(".")[1]
    numeCompletMirror = os.path.join(director,fisierMirror)
    rotated_image.save(numeCompletMirror)
    return fisierMirror

def prelucreazaImagineInput(fisier):
    fisierMirror = mirrorImage(fisier,directorImaginiInput)
    prelucreazaImagineInputAux(fisier)
    prelucreazaImagineInputAux(fisierMirror)

dictionarImagini={}  #dictionar[NumeImagine] = [intrarePiexeli,iesirePixelCarii]

def resizePoza(directorImagini,fisier,dimensiuneA):
    '''
    numeComplet = os.path.join(directorImagini,fisier)
    imagine=Image.open(numeComplet)#.convert('L')
    image_resized = imagine.resize(dimensiuneA,Image.ANTIALIAS)
    numeOutput = fisier.split(".")[0] + "aux"+"."+fisier.split(".")[1]
    numeComplet = os.path.join(directorImagini,numeOutput)
    image_resized.save(numeComplet)
    return numeOutput
    '''
    import cv2

    desired_size = dimensiuneA[0]
    im_pth = os.path.join(directorImagini,fisier)

    im = cv2.imread(im_pth)
    old_size = im.shape[:2] # old_size is in (height, width) format

    ratio = float(desired_size)/max(old_size)
    new_size = tuple([int(x*ratio) for x in old_size])

    # new_size should be in (width, height) format

    im = cv2.resize(im, (new_size[1], new_size[0]))

    delta_w = desired_size - new_size[1]
    delta_h = desired_size - new_size[0]
    top, bottom = delta_h//2, delta_h-(delta_h//2)
    left, right = delta_w//2, delta_w-(delta_w//2)

    color = [0, 0, 0]
    new_im = cv2.copyMakeBorder(im, top, bottom, left, right, cv2.BORDER_CONSTANT,
        value=color)
    numeOutput = fisier.split(".")[0] + "aux"+"."+fisier.split(".")[1]
    numeComplet = os.path.join(directorImagini,numeOutput)
    cv2.imwrite(numeComplet, new_im)
    return numeOutput
def mainInput():
    from os import listdir
    from os.path import isfile, join
    onlyfiles = [f for f in listdir(directorImaginiInput) if isfile(join(directorImaginiInput, f))]
    for fisier in onlyfiles:
        if (fisier.endswith("jpg") or fisier.endswith("png") ) and "aux" not in fisier:
            fisier = resizePoza(directorImaginiInput,fisier,dimensiune)
            prelucreazaImagineInput(fisier)
            
    onlyfiles = [f for f in listdir(directorImaginiOutput) if isfile(join(directorImaginiOutput, f))]
    for fisier in onlyfiles:
        if (fisier.endswith("jpg") or fisier.endswith("png") ) and "aux" not in fisier:
            fisier = resizePoza(directorImaginiOutput,fisier,dimensiuneOut)
            prelucreazaImagineOutput(fisier)
            
    intrare = []
    iesire = []
    for valori in dictionarImagini.values():
        if(not isinstance(valori[0],int)) and (not isinstance(valori[1], int)):
            intrare.append(valori[0])
            iesire.append(valori[1])
    intrare = numpy.array(intrare)
    iesire =numpy.array(iesire)
    print(len(intrare), len(iesire))
    return intrare,iesire


'''Retea
Created on Apr 24, 2019

@author: PITA
'''
from keras.models import Sequential, Model
from keras.layers import Dense, Activation, Conv2D, MaxPooling2D, Input,Flatten,Reshape,Dropout,BatchNormalization,Conv2DTranspose,UpSampling2D,concatenate
from keras import optimizers, losses
from keras import  regularizers
from keras.regularizers import l2
import keras.metrics
import keras.backend as K
import tensorflow as tf

dimensiune = (256,256)

def carenteTotale(y_true, y_pred):
    """
    a1 = K.sign(y_pred)
    a2 = K.equal(y_true,K.sign(y_pred))
    a3 = K.cast(K.equal(y_true,K.sign(y_pred)),tf.int16)
    a4 = K.sum(K.cast(K.equal(y_true,K.sign(y_pred)),tf.int16))
    K.print_tensor(y_pred)
    return K.sum(K.cast(K.equal(y_true,K.sign(y_pred)),tf.int16))
    """
    return K.sum(K.cast(K.equal(y_true, K.sign(y_pred)),K.floatx()))


def pusaCarieSiNuE(y_true, y_pred):
    aux1 = K.not_equal(y_true,K.sign(y_pred))
    return K.sum(K.cast(K.equal(aux1,K.cast(K.sign(y_pred),tf.bool)),K.floatx()))
    

def trebeCarieSiNaPus(y_true, y_pred):
    return carenteTotale(y_true, y_pred) + pusaCarieSiNuE(y_true, y_pred)
    '''
aux1 = K.not_equal(y_true,K.sign(y_pred))
aux2 =  K.not_equal(K.ones(K.shape(y_pred)),K.sign(y_pred))
return K.sum(K.cast(K.equal(aux1,aux2),tf.int16))
'''
def getModel():
    global model
    return model


from keras.optimizers import *
x=16 

inputs = Input((dimensiune[0], dimensiune[1], 1))
conv1 = Conv2D(x, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(inputs)
conv1 = Conv2D(x, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv1)
pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)
conv2 = Conv2D(x*2, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool1)
conv2 = Conv2D(x*2, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv2)
pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)
conv3 = Conv2D(x*4, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool2)
conv3 = Conv2D(x*4, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv3)
pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)
conv4 = Conv2D(x*8, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool3)
conv4 = Conv2D(x*8, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv4)
drop4 = Dropout(0.5)(conv4)
pool4 = MaxPooling2D(pool_size=(2, 2))(drop4)

conv5 = Conv2D(x*16, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool4)
conv5 = Conv2D(x*16, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv5)
drop5 = Dropout(0.5)(conv5)

up6 = Conv2D(x*8, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(drop5))
merge6 = concatenate([drop4,up6], axis = 3)
conv6 = Conv2D(x*8, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge6)
conv6 = Conv2D(x*8, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv6)

up7 = Conv2D(x*4, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv6))
merge7 = concatenate([conv3,up7], axis = 3)
conv7 = Conv2D(x*4, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge7)
conv7 = Conv2D(x*4, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv7)

up8 = Conv2D(x*2, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv7))
merge8 = concatenate([conv2,up8], axis = 3)
conv8 = Conv2D(x*2, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge8)
conv8 = Conv2D(x*2, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv8)

up9 = Conv2D(x, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv8))
merge9 = concatenate([conv1,up9], axis = 3)
conv9 = Conv2D(x, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge9)
conv9 = Conv2D(x, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv9)
conv9 = Conv2D(8, 3,activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv9)
conv9 = Conv2D(4, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv9)
conv9 = Conv2D(2, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv9)
conv9 = Conv2D(1, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv9)

conv9 = Flatten()(conv9)
conv9 = Dense(1024,activation='relu')(conv9)
conv9 = Dropout(0.5)(conv9)
conv9 = Dense(1024,activation='relu')(conv9)
conv9 = Dropout(0.5)(conv9)
conv9 = Dense(1024,activation='relu')(conv9)
conv9 = Dropout(0.5)(conv9)
conv9 = Dense(4096,activation='selu')(conv9)
conv9 = Reshape((64,64))(conv9)

# conv9 = Conv2D(2, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv9)
# conv10 = Conv2D(1, 1, activation = 'elu',name="myOutputLayer")(conv9)

model = Model(input = inputs, output = conv9)

sgd = optimizers.SGD(nesterov=True)
model.compile(optimizer = Adam(), loss = keras.losses.categorical_crossentropy, metrics = [carenteTotale,pusaCarieSiNuE,trebeCarieSiNaPus])
#model.compile(optimizer =sgd, loss = keras.losses.categorical_crossentropy, metrics = [carenteTotale,pusaCarieSiNuE,trebeCarieSiNaPus])

model.summary()

'''Antrenament
Created on May 2, 2019

@author: narci
'''
import imutils
import numpy
print(imutils.__version__)
#from Package.GetInput import mainInput
#from Package import Retea
#from Crypto.Random.random import shuffle
import tensorflow as tf
#from Package.MainScript import analizeazaPoza
from keras.models import model_from_json

def mainAntrenament() :
    #session = tf.Session(config=tf.ConfigProto(log_device_placement=True))
    intrare, iesire  = mainInput()
    #intrare = numpy.tile(intrare,10)
    #iesire = numpy.tile(iesire, 10)
    model = getModel()
    
    model.fit (intrare,iesire,epochs=10,batch_size=10,shuffle=True,validation_split=0.1)
    salveazaModel(model)

#folder = r'C:\Users\PITA\git\licenta2019\Radiografii_DB'
def  deleteAuxFiles(folder):
    import os, shutil
    for the_file in os.listdir(folder):
        file_path = os.path.join(folder, the_file)
        try:
            if os.path.isfile(file_path):
                if "aux" in file_path:
                    os.unlink(file_path)
            #elif os.path.isdir(file_path): shutil.rmtree(file_path)
        except Exception as e:
            print(e)
    print("Done")
    
   
   
def salveazaModel(model):     
        # serialize model to JSON
        model_json = model.to_json()
        with open("model3.json", "w") as json_file:
            json_file.write(model_json)
        # serialize weights to HDF5
        model.save_weights("/content/drive/My Drive/Colab Notebooks/licenta2019/model3.h5")
        print("Saved model to disk")
 
def incarcaModel():
    # load json and create model
    json_file = open('model.json', 'r')
    loaded_model_json = json_file.read()
    json_file.close()
    loaded_model = model_from_json(loaded_model_json)
    # load weights into new model
    loaded_model.load_weights("model.h5")
    print("Loaded model from disk")
    return loaded_model
    

mainAntrenament()
#analizeazaPoza(r"/content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB/PHOTO-2019-04-20-15-56-23.jpg")
#deleteAuxFiles("/content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB") 
#deleteAuxFiles("/content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output")
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:380: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("re...)`
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_5 (InputLayer)            (None, 256, 256, 1)  0
# __________________________________________________________________________________________________
# conv2d_105 (Conv2D)             (None, 256, 256, 16) 160         input_5[0][0]
# __________________________________________________________________________________________________
# conv2d_106 (Conv2D)             (None, 256, 256, 16) 2320        conv2d_105[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_17 (MaxPooling2D) (None, 128, 128, 16) 0           conv2d_106[0][0]
# __________________________________________________________________________________________________
# conv2d_107 (Conv2D)             (None, 128, 128, 32) 4640        max_pooling2d_17[0][0]
# __________________________________________________________________________________________________
# conv2d_108 (Conv2D)             (None, 128, 128, 32) 9248        conv2d_107[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_18 (MaxPooling2D) (None, 64, 64, 32)   0           conv2d_108[0][0]
# __________________________________________________________________________________________________
# conv2d_109 (Conv2D)             (None, 64, 64, 64)   18496       max_pooling2d_18[0][0]
# __________________________________________________________________________________________________
# conv2d_110 (Conv2D)             (None, 64, 64, 64)   36928       conv2d_109[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_19 (MaxPooling2D) (None, 32, 32, 64)   0           conv2d_110[0][0]
# __________________________________________________________________________________________________
# conv2d_111 (Conv2D)             (None, 32, 32, 128)  73856       max_pooling2d_19[0][0]
# __________________________________________________________________________________________________
# conv2d_112 (Conv2D)             (None, 32, 32, 128)  147584      conv2d_111[0][0]
# __________________________________________________________________________________________________
# dropout_21 (Dropout)            (None, 32, 32, 128)  0           conv2d_112[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_20 (MaxPooling2D) (None, 16, 16, 128)  0           dropout_21[0][0]
# __________________________________________________________________________________________________
# conv2d_113 (Conv2D)             (None, 16, 16, 256)  295168      max_pooling2d_20[0][0]
# __________________________________________________________________________________________________
# conv2d_114 (Conv2D)             (None, 16, 16, 256)  590080      conv2d_113[0][0]
# __________________________________________________________________________________________________
# dropout_22 (Dropout)            (None, 16, 16, 256)  0           conv2d_114[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_17 (UpSampling2D) (None, 32, 32, 256)  0           dropout_22[0][0]
# __________________________________________________________________________________________________
# conv2d_115 (Conv2D)             (None, 32, 32, 128)  131200      up_sampling2d_17[0][0]
# __________________________________________________________________________________________________
# concatenate_17 (Concatenate)    (None, 32, 32, 256)  0           dropout_21[0][0]
#                                                                  conv2d_115[0][0]
# __________________________________________________________________________________________________
# conv2d_116 (Conv2D)             (None, 32, 32, 128)  295040      concatenate_17[0][0]
# __________________________________________________________________________________________________
# conv2d_117 (Conv2D)             (None, 32, 32, 128)  147584      conv2d_116[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_18 (UpSampling2D) (None, 64, 64, 128)  0           conv2d_117[0][0]
# __________________________________________________________________________________________________
# conv2d_118 (Conv2D)             (None, 64, 64, 64)   32832       up_sampling2d_18[0][0]
# __________________________________________________________________________________________________
# concatenate_18 (Concatenate)    (None, 64, 64, 128)  0           conv2d_110[0][0]
#                                                                  conv2d_118[0][0]
# __________________________________________________________________________________________________
# conv2d_119 (Conv2D)             (None, 64, 64, 64)   73792       concatenate_18[0][0]
# __________________________________________________________________________________________________
# conv2d_120 (Conv2D)             (None, 64, 64, 64)   36928       conv2d_119[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_19 (UpSampling2D) (None, 128, 128, 64) 0           conv2d_120[0][0]
# __________________________________________________________________________________________________
# conv2d_121 (Conv2D)             (None, 128, 128, 32) 8224        up_sampling2d_19[0][0]
# __________________________________________________________________________________________________
# concatenate_19 (Concatenate)    (None, 128, 128, 64) 0           conv2d_108[0][0]
#                                                                  conv2d_121[0][0]
# __________________________________________________________________________________________________
# conv2d_122 (Conv2D)             (None, 128, 128, 32) 18464       concatenate_19[0][0]
# __________________________________________________________________________________________________
# conv2d_123 (Conv2D)             (None, 128, 128, 32) 9248        conv2d_122[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_20 (UpSampling2D) (None, 256, 256, 32) 0           conv2d_123[0][0]
# __________________________________________________________________________________________________
# conv2d_124 (Conv2D)             (None, 256, 256, 16) 2064        up_sampling2d_20[0][0]
# __________________________________________________________________________________________________
# concatenate_20 (Concatenate)    (None, 256, 256, 32) 0           conv2d_106[0][0]
#                                                                  conv2d_124[0][0]
# __________________________________________________________________________________________________
# conv2d_125 (Conv2D)             (None, 256, 256, 16) 4624        concatenate_20[0][0]
# __________________________________________________________________________________________________
# conv2d_126 (Conv2D)             (None, 256, 256, 16) 2320        conv2d_125[0][0]
# __________________________________________________________________________________________________
# conv2d_127 (Conv2D)             (None, 256, 256, 8)  1160        conv2d_126[0][0]
# __________________________________________________________________________________________________
# conv2d_128 (Conv2D)             (None, 256, 256, 4)  292         conv2d_127[0][0]
# __________________________________________________________________________________________________
# conv2d_129 (Conv2D)             (None, 256, 256, 2)  74          conv2d_128[0][0]
# __________________________________________________________________________________________________
# conv2d_130 (Conv2D)             (None, 256, 256, 1)  19          conv2d_129[0][0]
# __________________________________________________________________________________________________
# flatten_5 (Flatten)             (None, 65536)        0           conv2d_130[0][0]
# __________________________________________________________________________________________________
# dense_17 (Dense)                (None, 1024)         67109888    flatten_5[0][0]
# __________________________________________________________________________________________________
# dropout_23 (Dropout)            (None, 1024)         0           dense_17[0][0]
# __________________________________________________________________________________________________
# dense_18 (Dense)                (None, 1024)         1049600     dropout_23[0][0]
# __________________________________________________________________________________________________
# dropout_24 (Dropout)            (None, 1024)         0           dense_18[0][0]
# __________________________________________________________________________________________________
# dense_19 (Dense)                (None, 1024)         1049600     dropout_24[0][0]
# __________________________________________________________________________________________________
# dropout_25 (Dropout)            (None, 1024)         0           dense_19[0][0]
# __________________________________________________________________________________________________
# dense_20 (Dense)                (None, 4096)         4198400     dropout_25[0][0]
# __________________________________________________________________________________________________
# reshape_5 (Reshape)             (None, 64, 64)       0           dense_20[0][0]
# ==================================================================================================
# Total params: 75,349,833
# Trainable params: 75,349,833
# Non-trainable params: 0
# __________________________________________________________________________________________________
# 0.5.2
# 99.0
# 3.0
# 114.66666666666666
# 49.5
# 1.0
# 35.5
# 138.66666666666666
# 3.0
# 69.0
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-04-20-15-56-23aux.jpg
# [[33, 38], [49, 35], [46, 23]]
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-04-20-15-56-23auxmirror.jpg
# []
# 102.0
# 3.0
# 86.33333333333333
# 156.0
# 4.0
# 114.0
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-04-20-15-56-49aux.jpg
# [[34, 28], [39, 28]]
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-04-20-15-56-49auxmirror.jpg
# []
# 390.0
# 10.0
# 400.0
# 327.3333333333333
# 14.5
# 550.1666666666666
# 134.33333333333331
# 5.0
# 117.5
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-04-24-14-12-50aux.jpg
# [[39, 40], [22, 37], [26, 23]]
# 240.0
# 10.0
# 400.0
# 480.0
# 12.0
# 450.0
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-04-24-14-12-50auxmirror.jpg
# [[24, 40], [40, 37]]
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-04-24-14-13-09aux.jpg
# []
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-04-24-14-13-09auxmirror.jpg
# []
# 50.5
# 1.0
# 40.5
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-04-24-14-14-04aux.jpg
# [[50, 40]]
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-04-24-14-14-04auxmirror.jpg
# []
# 112.0
# 4.0
# 120.0
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-04-24-14-15-07aux.jpg
# [[28, 30]]
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-04-24-14-15-07auxmirror.jpg
# []
# 20.5
# 1.0
# 36.5
# 0.0
# 0.0
# 0.0
# 10.5
# 1.0
# 32.5
# 130.0
# 4.0
# 128.0
# 126.5
# 5.0
# 162.5
# 24.333333333333332
# 0.5
# 14.333333333333332
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-04-20-15-57-26aux.jpg
# [[20, 36], [10, 32], [32, 32], [25, 32], [48, 28]]
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-04-20-15-57-26auxmirror.jpg
# []
# 6.5
# 1.0
# 44.5
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-04-20-15-57-06aux.jpg
# [[6, 44]]
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-04-20-15-57-06auxmirror.jpg
# []
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-04-24-14-15-58aux.jpg
# []
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-04-24-14-15-58auxmirror.jpg
# []
# 364.8333333333333
# 10.5
# 146.0
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-04-24-14-13-38aux.jpg
# [[34, 13]]
# 243.33333333333331
# 8.5
# 119.33333333333333
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-04-24-14-13-38auxmirror.jpg
# [[28, 14]]
# 36.5
# 1.0
# 30.5
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-04-24-14-14-26aux.jpg
# [[36, 30]]
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-04-24-14-14-26auxmirror.jpg
# []
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-04-24-14-15-32aux.jpg
# []
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-04-24-14-15-32auxmirror.jpg
# []
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-04-24-14-14-46aux.jpg
# []
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-04-24-14-14-46auxmirror.jpg
# []
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-04-24-14-17-20aux.jpg
# []
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-04-24-14-17-20auxmirror.jpg
# []
# 12.5
# 1.0
# 32.5
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-04-24-14-18-08aux.jpg
# [[12, 32]]
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-04-24-14-18-08auxmirror.jpg
# []
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-05-02-10-35-28aux.jpg
# []
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-05-02-10-35-28auxmirror.jpg
# []
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-05-02-10-42-19aux.jpg
# []
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-05-02-10-42-19auxmirror.jpg
# []
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-04-24-14-16-31aux.jpg
# []
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-04-24-14-16-31auxmirror.jpg
# []
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-04-24-14-17-39aux.jpg
# []
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-04-24-14-17-39auxmirror.jpg
# []
# 132.66666666666666
# 3.0
# 99.0
# 101.83333333333333
# 7.5
# 243.16666666666666
# 84.0
# 4.0
# 114.0
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-05-02-10-34-39aux.jpg
# [[44, 33], [13, 32], [21, 28]]
# 247.5
# 5.0
# 164.33333333333331
# 82.66666666666666
# 4.5
# 148.16666666666666
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-05-02-10-34-39auxmirror.jpg
# [[49, 32], [18, 32]]
# 716.0
# 13.0
# 570.5
# 492.66666666666663
# 10.0
# 401.5
# 324.0
# 8.0
# 314.8333333333333
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-05-02-10-35-05aux.jpg
# [[55, 43], [49, 40], [40, 39]]
# 124.66666666666666
# 16.0
# 709.5
# 202.5
# 9.0
# 355.5
# 141.5
# 10.0
# 397.3333333333333
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-05-02-10-35-05auxmirror.jpg
# [[7, 44], [22, 39], [14, 39]]
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-05-02-10-48-48aux.jpg
# []
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-05-02-10-48-48auxmirror.jpg
# []
# 32.5
# 1.0
# 44.5
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-05-02-10-47-34aux.jpg
# [[32, 44]]
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-05-02-10-47-34auxmirror.jpg
# []
# 150.33333333333331
# 11.5
# 244.83333333333331
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-05-02-10-35-49aux.jpg
# [[13, 21]]
# 624.1666666666666
# 12.5
# 266.3333333333333
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-05-02-10-35-49auxmirror.jpg
# [[49, 21]]
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-05-02-10-49-05aux.jpg
# []
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-05-02-10-49-05auxmirror.jpg
# []
# 32.5
# 1.0
# 30.5
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-05-02-10-49-57aux.jpg
# [[32, 30]]
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-05-02-10-49-57auxmirror.jpg
# []
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-05-02-10-51-25aux.jpg
# []
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-05-02-10-51-25auxmirror.jpg
# []
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-05-02-10-49-19aux.jpg
# []
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-05-02-10-49-19auxmirror.jpg
# []
# 12.333333333333332
# 0.5
# 14.333333333333332
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-05-02-10-49-42aux.jpg
# [[24, 28]]
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-05-02-10-49-42auxmirror.jpg
# []
# 10.5
# 1.0
# 34.5
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-05-02-10-51-51aux.jpg
# [[10, 34]]
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-05-02-10-51-51auxmirror.jpg
# []
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-05-02-10-50-14aux.jpg
# []
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-05-02-10-50-14auxmirror.jpg
# []
# 30.5
# 1.0
# 44.5
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-05-02-10-50-39aux.jpg
# [[30, 44]]
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-05-02-10-50-39auxmirror.jpg
# []
# 14.5
# 1.0
# 42.5
# 165.5
# 4.0
# 162.83333333333331
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-05-02-10-52-55aux.jpg
# [[14, 42], [41, 40]]
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-05-02-10-52-55auxmirror.jpg
# []
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-05-02-10-52-10aux.jpg
# []
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-05-02-10-52-10auxmirror.jpg
# []
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-05-02-10-52-34aux.jpg
# []
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-05-02-10-52-34auxmirror.jpg
# []
# 38.5
# 1.0
# 32.5
# 26.5
# 1.0
# 32.5
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-05-02-11-03-37aux.jpg
# [[38, 32], [26, 32]]
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-05-02-11-03-37auxmirror.jpg
# []
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-05-02-11-04-11aux.jpg
# []
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-05-02-11-04-11auxmirror.jpg
# []
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-05-02-11-05-31aux.jpg
# []
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-05-02-11-05-31auxmirror.jpg
# []
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-05-02-11-03-12aux.jpg
# []
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-05-02-11-03-12auxmirror.jpg
# []
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-05-02-10-53-36aux.jpg
# []
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-05-02-10-53-36auxmirror.jpg
# []
# 41.5
# 1.0
# 32.5
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-05-02-11-05-54aux.jpg
# [[41, 32]]
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-05-02-11-05-54auxmirror.jpg
# []
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-05-02-11-05-01aux.jpg
# []
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-05-02-11-05-01auxmirror.jpg
# []
# 26.5
# 1.0
# 21.5
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-05-02-11-04-33aux.jpg
# [[26, 21]]
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-05-02-11-04-33auxmirror.jpg
# []
# 0.0
# 0.0
# 0.0
# 126.0
# 3.0
# 86.33333333333333
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-05-02-11-07-07aux.jpg
# [[42, 28]]
# 13.666666666666666
# 0.5
# 15.333333333333332
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-05-02-11-07-07auxmirror.jpg
# [[27, 30]]
# 24.333333333333332
# 0.5
# 17.333333333333332
# 28.5
# 1.0
# 31.5
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-05-02-11-07-57aux.jpg
# [[48, 34], [28, 31]]
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-05-02-11-07-57auxmirror.jpg
# []
# 19.166666666666664
# 1.5
# 51.666666666666664
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-05-02-11-06-39aux.jpg
# [[12, 34]]
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-05-02-11-06-39auxmirror.jpg
# []
# 9.666666666666666
# 0.5
# 14.333333333333332
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-05-02-11-06-17aux.jpg
# [[19, 28]]
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-05-02-11-06-17auxmirror.jpg
# []
# 215.0
# 5.0
# 171.33333333333331
# 144.0
# 3.0
# 98.33333333333333
# 78.0
# 4.0
# 132.0
# 56.5
# 1.0
# 29.5
# 114.0
# 4.0
# 120.0
# 120.0
# 12.0
# 354.0
# 185.83333333333331
# 3.5
# 90.66666666666666
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-05-02-11-08-46aux.jpg
# [[43, 34], [48, 32], [19, 33], [56, 29], [28, 30], [10, 29], [53, 25]]
# 6.5
# 1.0
# 29.5
# 531.5
# 10.0
# 297.3333333333333
# 10.5
# 1.0
# 25.5
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-05-02-11-08-46auxmirror.jpg
# [[6, 29], [53, 29], [10, 25]]
# 220.66666666666666
# 6.0
# 235.33333333333331
# 174.5
# 9.0
# 310.0
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-05-02-11-08-21aux.jpg
# [[36, 39], [19, 34]]
# 78.0
# 3.0
# 117.66666666666666
# 564.5
# 13.0
# 444.8333333333333
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-05-02-11-08-21auxmirror.jpg
# [[26, 39], [43, 34]]
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-05-02-11-07-31aux.jpg
# []
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-05-02-11-07-31auxmirror.jpg
# []
# 66.33333333333333
# 1.5
# 45.666666666666664
# 19.166666666666664
# 0.5
# 15.333333333333332
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-05-02-11-09-38aux.jpg
# [[44, 30], [38, 30]]
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-05-02-11-09-38auxmirror.jpg
# []
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-05-02-11-11-26aux.jpg
# []
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-05-02-11-11-26auxmirror.jpg
# []
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-05-02-11-09-16aux.jpg
# []
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-05-02-11-09-16auxmirror.jpg
# []
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-05-02-11-10-00aux.jpg
# []
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-05-02-11-10-00auxmirror.jpg
# []
# 215.0
# 5.0
# 181.33333333333331
# 51.5
# 1.0
# 33.5
# 62.33333333333333
# 3.0
# 75.0
# 348.0
# 8.0
# 197.16666666666666
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-05-02-11-11-48aux.jpg
# [[43, 36], [51, 33], [20, 25], [43, 24]]
# 138.66666666666666
# 7.0
# 256.0
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-05-02-11-11-48auxmirror.jpg
# [[19, 36]]
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-05-02-11-10-33aux.jpg
# []
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-05-02-11-10-33auxmirror.jpg
# []
# 38.5
# 1.0
# 16.5
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-05-02-11-11-00aux.jpg
# [[38, 16]]
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-05-02-11-11-00auxmirror.jpg
# []
# 26.5
# 1.0
# 28.5
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-05-02-11-12-09aux.jpg
# [[26, 28]]
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-05-02-11-12-09auxmirror.jpg
# []
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-05-02-11-13-26aux.jpg
# []
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-05-02-11-13-26auxmirror.jpg
# []
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-05-02-11-12-38aux.jpg
# []
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-05-02-11-12-38auxmirror.jpg
# []
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-05-02-11-13-05aux.jpg
# []
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-05-02-11-13-05auxmirror.jpg
# []
# 0.0
# 0.0
# 0.0
# 36.5
# 1.0
# 30.5
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-05-02-11-15-16aux.jpg
# [[36, 30]]
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-05-02-11-15-16auxmirror.jpg
# []
# 105.0
# 3.0
# 102.66666666666666
# 87.0
# 3.0
# 96.66666666666666
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-05-02-11-14-10aux.jpg
# [[35, 34], [29, 32]]
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-05-02-11-14-10auxmirror.jpg
# []
# 52.5
# 1.0
# 30.5
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-05-02-11-13-48aux.jpg
# [[52, 30]]
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-05-02-11-13-48auxmirror.jpg
# []
# 40.5
# 1.0
# 40.5
# 26.5
# 1.0
# 38.5
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-05-02-11-15-16_2aux.jpg
# [[40, 40], [26, 38]]
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-05-02-11-15-16_2auxmirror.jpg
# []
# 20.5
# 1.0
# 34.5
# 34.5
# 1.0
# 31.5
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-05-02-11-17-01aux.jpg
# [[20, 34], [34, 31]]
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-05-02-11-17-01auxmirror.jpg
# []
# 387.5
# 8.0
# 102.0
# 32.5
# 1.0
# 8.5
# 0.0
# 0.0
# 0.0
# 224.16666666666666
# 11.5
# 95.33333333333333
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-05-02-11-15-17aux.jpg
# [[48, 12], [32, 8], [19, 8]]
# 106.66666666666666
# 7.5
# 99.33333333333333
# 132.0
# 3.0
# 24.666666666666664
# 171.33333333333331
# 4.5
# 34.33333333333333
# 111.66666666666666
# 3.5
# 24.166666666666664
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-05-02-11-15-17auxmirror.jpg
# [[14, 13], [44, 8], [38, 7], [31, 6]]
# 69.0
# 3.0
# 86.33333333333333
# 10.5
# 1.0
# 28.5
# 26.666666666666664
# 1.5
# 41.33333333333333
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-05-02-11-15-16_1aux.jpg
# [[23, 28], [10, 28], [17, 27]]
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-05-02-11-15-16_1auxmirror.jpg
# []
# 45.0
# 3.0
# 83.33333333333333
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-05-02-11-17-01_1aux.jpg
# [[15, 27]]
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-05-02-11-17-01_1auxmirror.jpg
# []
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-05-02-11-17-02aux.jpg
# []
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-05-02-11-17-02auxmirror.jpg
# []
# 24.5
# 1.0
# 30.5
# 14.5
# 1.0
# 30.5
# 111.0
# 3.0
# 80.33333333333333
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-05-02-11-17-01_2aux.jpg
# [[24, 30], [14, 30], [37, 26]]
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-05-02-11-17-01_2auxmirror.jpg
# []
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-05-02-11-17-02_1aux.jpg
# []
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-05-02-11-17-02_1auxmirror.jpg
# []
# 50.5
# 1.0
# 30.5
# 227.5
# 5.0
# 137.5
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-05-02-11-17-02_3aux.jpg
# [[50, 30], [45, 27]]
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-05-02-11-17-02_3auxmirror.jpg
# []
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-05-02-11-17-02_2aux.jpg
# []
# /content/drive/My Drive/Colab Notebooks/licenta2019/Radiografii_DB_Output/PHOTO-2019-05-02-11-17-02_2auxmirror.jpg
# []
# 148 148
# Train on 133 samples, validate on 15 samples
# Epoch 1/10
# 133/133 [==============================] - 144s 1s/step - loss: -842.5527 - carenteTotale: 32124.7594 - pusaCarieSiNuE: 8188.5038 - trebeCarieSiNaPus: 40313.2632 - val_loss: -956.4956 - val_carenteTotale: 32216.0000 - val_pusaCarieSiNuE: 1917.3333 - val_trebeCarieSiNaPus: 34133.3333
# Epoch 2/10
# 133/133 [==============================] - 138s 1s/step - loss: -961.5834 - carenteTotale: 38356.6090 - pusaCarieSiNuE: 1956.6541 - trebeCarieSiNaPus: 40313.2632 - val_loss: -963.3802 - val_carenteTotale: 32484.3333 - val_pusaCarieSiNuE: 1649.0000 - val_trebeCarieSiNaPus: 34133.3333
# Epoch 3/10
# 133/133 [==============================] - 138s 1s/step - loss: -961.5496 - carenteTotale: 38605.6917 - pusaCarieSiNuE: 1707.5714 - trebeCarieSiNaPus: 40313.2632 - val_loss: -955.8750 - val_carenteTotale: 32633.0000 - val_pusaCarieSiNuE: 1500.3333 - val_trebeCarieSiNaPus: 34133.3333
# Epoch 4/10
# 133/133 [==============================] - 139s 1s/step - loss: -961.9030 - carenteTotale: 38725.1805 - pusaCarieSiNuE: 1588.0827 - trebeCarieSiNaPus: 40313.2632 - val_loss: -957.7852 - val_carenteTotale: 32704.6667 - val_pusaCarieSiNuE: 1428.6667 - val_trebeCarieSiNaPus: 34133.3333
# Epoch 5/10
# 133/133 [==============================] - 137s 1s/step - loss: -962.7914 - carenteTotale: 38801.7669 - pusaCarieSiNuE: 1511.4962 - trebeCarieSiNaPus: 40313.2632 - val_loss: -959.9451 - val_carenteTotale: 32782.6667 - val_pusaCarieSiNuE: 1350.6667 - val_trebeCarieSiNaPus: 34133.3333
# Epoch 6/10
# 133/133 [==============================] - 137s 1s/step - loss: -965.0766 - carenteTotale: 38912.8496 - pusaCarieSiNuE: 1400.4135 - trebeCarieSiNaPus: 40313.2632 - val_loss: -962.2377 - val_carenteTotale: 32869.0000 - val_pusaCarieSiNuE: 1264.3333 - val_trebeCarieSiNaPus: 34133.3333
# Epoch 7/10
# 133/133 [==============================] - 137s 1s/step - loss: -966.0866 - carenteTotale: 38956.0602 - pusaCarieSiNuE: 1357.2030 - trebeCarieSiNaPus: 40313.2632 - val_loss: -962.7277 - val_carenteTotale: 32885.6667 - val_pusaCarieSiNuE: 1247.6667 - val_trebeCarieSiNaPus: 34133.3333
# Epoch 8/10
# 133/133 [==============================] - 137s 1s/step - loss: -967.5093 - carenteTotale: 38977.2256 - pusaCarieSiNuE: 1336.0376 - trebeCarieSiNaPus: 40313.2632 - val_loss: -963.2308 - val_carenteTotale: 32904.6667 - val_pusaCarieSiNuE: 1228.6667 - val_trebeCarieSiNaPus: 34133.3333
# Epoch 9/10
# 133/133 [==============================] - 137s 1s/step - loss: -968.3296 - carenteTotale: 39012.1053 - pusaCarieSiNuE: 1301.1579 - trebeCarieSiNaPus: 40313.2632 - val_loss: -963.2380 - val_carenteTotale: 32904.6667 - val_pusaCarieSiNuE: 1228.6667 - val_trebeCarieSiNaPus: 34133.3333
# Epoch 10/10
# 133/133 [==============================] - 137s 1s/step - loss: -969.4177 - carenteTotale: 39013.0902 - pusaCarieSiNuE: 1300.1729 - trebeCarieSiNaPus: 40313.2632 - val_loss: -963.3939 - val_carenteTotale: 32909.6667 - val_pusaCarieSiNuE: 1223.6667 - val_trebeCarieSiNaPus: 34133.3333
# Saved model to disk
